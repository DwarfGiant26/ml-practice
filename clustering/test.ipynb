# %%
# %load_ext autoreload
# %autoreload 2

from k_means import *
from helper_class import *

# %%
# Initial setup

points = ClusteringTestGenerator.generate_points(num_clusters=10, num_points=1000)
print(points.shape)
# Out:
# (1000, 2)

# %%
clusters:list[Cluster] = KMeans.k_means(points, 10)

# %%
ClusteringVizHelper.plot_clusters(clusters)
