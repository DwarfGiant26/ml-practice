# %%
# %load_ext autoreload
# %autoreload 2

from k_means import *
from helper_class import *

# %%
# Initial setup
num_points = 1000
num_clusters = 10

sphere_points = ClusteringTestGenerator.generate_points(num_clusters, num_points)
streched_points = ClusteringTestGenerator.generate_streched_points(num_clusters, num_points)
moon_points = ClusteringTestGenerator.generate_moon_points(num_points)

# %%
sphere_clusters:list[Cluster] = KMeans.k_means(sphere_points, num_clusters)
streched_clusters:list[Cluster] = KMeans.k_means(streched_points, num_clusters)
moon_clusters: list[Cluster] = KMeans.k_means(moon_points, 2)

# %%
ClusteringVizHelper.plot_clusters(sphere_clusters)

# %%
ClusteringVizHelper.plot_clusters(streched_clusters)

# %%
ClusteringVizHelper.plot_clusters(moon_clusters)
